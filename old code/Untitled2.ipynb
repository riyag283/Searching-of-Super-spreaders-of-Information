# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('infmap4.csv',index_col=0)

# %%
import numpy as np
a = np.arange(0,56)
df1 = df[df.columns[0:56]]

# %%
plt.imshow(df1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
56/5
# Out:
# 11.2

# %%
df = pd.read_csv('pr.csv',index_col=0)

# %%
df
# Out:
#       node name  kshell                                           in-nodes  \
# 0          1300       1                                                 []
# 1            52       1                                               [54]
# 2          4389       1                                                 []
# 3            63       1                                                [6]
# 4            84       1                                               [33]
# 5            85       1                                               [33]
# 6            88       1                                               [33]
# 7            82       1                                               [93]
# 8          4896       1                                                 []
# 9           117       1                                               [95]
# 10          118       1                                               [95]
# 11          119       1                                               [95]
# 12          112       1                                               [95]
# 13          123       1                                               [95]
# 14          114       1                                               [95]
# 15          137       1                                              [144]
# 16          141       1                                              [144]
# 17          146       1                                              [147]
# 18          149       1                                              [151]
# 19         7672       1                                                 []
# 20          159       1                                              [153]
# 21          160       1                                              [153]
# 22          174       1                                              [175]
# 23          189       1                                              [214]
# 24          196       1                                              [214]
# 25          195       1                                              [214]
# 26          198       1                                              [214]
# 27          200       1                                              [214]
# 28          206       1                                              [214]
# 29          207       1                                              [214]
# ...         ...     ...                                                ...
# 7085       3276      56  [1140, 1157, 1307, 1549, 1990, 2072, 2134, 221...
# 7086       2576      56  [56, 765, 974, 1159, 1166, 1211, 1297, 1315, 1...
# 7087       2256      56  [15, 56, 214, 350, 403, 425, 741, 765, 778, 82...
# 7088       2790      56  [15, 204, 417, 465, 633, 741, 762, 827, 856, 9...
# 7089       2654      56  [285, 417, 762, 825, 827, 1267, 1291, 1297, 13...
# 7090       2700      56  [204, 285, 465, 608, 778, 825, 974, 1100, 1157...
# 7091       2747      56  [974, 1100, 1297, 1729, 1744, 2145, 2257, 2289...
# 7092       2290      56  [204, 825, 827, 974, 1100, 1157, 1166, 1297, 1...
# 7093       2510      56  [403, 765, 1166, 1186, 1250, 1267, 1297, 1416,...
# 7094       2713      56  [204, 285, 417, 465, 825, 827, 978, 1100, 1157...
# 7095       2326      56  [204, 285, 417, 608, 762, 825, 827, 974, 1031,...
# 7096       2674      56  [633, 825, 856, 1166, 1267, 1291, 1297, 1305, ...
# 7097        766      56  [15, 72, 86, 155, 204, 271, 285, 332, 346, 350...
# 7098        988      56  [204, 290, 332, 417, 465, 633, 722, 737, 762, ...
# 7099       2688      56  [72, 204, 285, 290, 346, 417, 465, 608, 633, 7...
# 7100       2967      56  [417, 762, 825, 974, 1157, 1166, 1239, 1297, 1...
# 7101       1549      56  [15, 56, 64, 171, 204, 214, 290, 298, 332, 350...
# 7102       2651      56  [15, 204, 285, 290, 403, 417, 465, 608, 737, 7...
# 7103        825      56  [15, 72, 417, 465, 737, 826, 827, 1026, 1166, ...
# 7104       2328      56  [332, 350, 403, 465, 722, 744, 765, 825, 859, ...
# 7105       2411      56  [417, 465, 825, 974, 1140, 1166, 1297, 1385, 1...
# 7106       2485      56  [204, 290, 417, 465, 737, 762, 765, 825, 856, ...
# 7107       2565      56  [56, 155, 204, 214, 285, 290, 346, 403, 417, 4...
# 7108       2653      56  [204, 417, 608, 737, 778, 825, 1166, 1267, 129...
# 7109       2871      56  [72, 204, 214, 290, 465, 608, 633, 737, 762, 8...
# 7110       3026      56  [72, 290, 608, 737, 825, 856, 974, 1157, 1247,...
# 7111       3028      56  [72, 417, 465, 525, 608, 737, 762, 825, 978, 1...
# 7112       3352      56  [72, 285, 417, 465, 608, 762, 825, 827, 974, 1...
# 7113       1166      56  [15, 56, 72, 204, 214, 222, 285, 290, 332, 346...
# 7114       2297      56  [15, 204, 214, 332, 417, 425, 465, 608, 737, 8...
#
#       Kin     m   ksum    pr
# 0       0     1      0  2375
# 1       1  2234      7  2410
# 2       0     1      0  2364
# 3       1     1    302  2418
# 4       1  2244     24  2430
# 5       1  2247     24  2431
# 6       1  2243     24  2434
# 7       1     2      1  2437
# 8       0     1      0  2378
# 9       1     3      2  2450
# 10      1     2      2  2451
# 11      1  2233      2  2452
# 12      1     1      2  2458
# 13      1     1      2  2462
# 14      1  2243      2  2464
# 15      1     1      0  2471
# 16      1     1      0  2474
# 17      1  2242     58  2478
# 18      1  2230     74  2479
# 19      0     1      0  2275
# 20      1     1      1  2483
# 21      1     1      1  2484
# 22      1     1      1  2490
# 23      1     2      0  2501
# 24      1     2      0  2502
# 25      1     1      0  2505
# 26      1     1      0  2506
# 27      1     1      0  2509
# 28      1     1      0  2514
# 29      1     1      0  2515
# ...   ...   ...    ...   ...
# 7085   79  2238   4615   313
# 7086  146  2234   5971    66
# 7087  247  2232   7941   132
# 7088  173  2250   7418   146
# 7089  104  2242   4830    26
# 7090  168  2245   7081  1055
# 7091   79  2239   4480   422
# 7092  120  2243   6044   649
# 7093   68  2249   5034   703
# 7094  200  2244   9465  1047
# 7095  252  2232  10647   902
# 7096  103  2248   7571   758
# 7097  773  2237  31666  2811
# 7098  292  2233  13818  2917
# 7099  618  2237  25327  3897
# 7100  238  2245  13935  4058
# 7101  587  2242  26392    51
# 7102  269  2238  12145    71
# 7103  165  2242   9791   104
# 7104  215  2255  11805    11
# 7105  141  2242   5496   221
# 7106  324  2242  15947    91
# 7107  893  2245  29982    36
# 7108  113  2245   7965   189
# 7109  282  2233  11435    84
# 7110  175  2242   9648   149
# 7111  189  2234   8742   445
# 7112  273  2237  12749    23
# 7113  599  2241  25004   303
# 7114  164  2236   8407   249
#
# [7115 rows x 7 columns]

# %%
# Python program to get average of a list 
def Average(lst): 
	return sum(lst) / len(lst) 

# Driver Code 
lst = [15, 9, 55, 41, 35, 20, 62, 49] 
average = Average(lst) 

# Printing average of the list 
print("Average of the list =", round(average, 2))
# Out:
# Average of the list = 35.75

# %%
Average(df['Kin'])
# Out:
# 14.573014757554462
